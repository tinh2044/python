# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ts = pd.Series(np.random.randn(100), index=pd.date_range("1/1/2000", periods=100))

new_ts = ts.cumsum()
new_ts.plot()
# Out:
# <AxesSubplot: >

# %%
# On a DataFrame, the plot() method is a convenience to plot all of the columns with labels:
df = pd.DataFrame(np.random.randn(1000,4), columns=list("ABCD"))
df
# Out:
#             A         B         C         D
# 0    0.996590 -1.559584 -0.063069 -1.044124
# 1   -1.287150 -1.081251 -0.277354  0.555513
# 2   -0.544917 -2.022351  1.320600  0.180405
# 3   -0.633045  0.298402  0.857618  1.823603
# 4    0.699272 -0.189366  0.845569  0.235893
# ..        ...       ...       ...       ...
# 995  0.169847  1.965215  0.944727  0.376181
# 996  0.238586  0.510677  0.755729 -0.048852
# 997 -1.060359  0.288822 -1.307496  1.239201
# 998  1.647720 -1.700240 -1.006503 -0.810145
# 999  2.194568  1.073154  1.212665 -0.327341
#
# [1000 rows x 4 columns]

# %%
plt.figure();

df.cumsum().plot();
